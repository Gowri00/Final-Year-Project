# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("wireshark.csv")

# %%
df.head()
df["Info"]=str(df["Info"]).split('=')[1][:4]

# %%
# str(df["Info"]).split('=')[1][:4]
df
# Out:
#        No.        Time           Source      Destination Protocol  Length  \
# 0        1    0.000000    192.168.137.1  239.255.255.250     SSDP     217
# 1        2    0.384720   192.168.137.64   142.250.183.14      UDP    1285
# 2        3    0.385031   192.168.137.64   142.250.183.14      UDP    1292
# 3        4    0.385232   192.168.137.64   142.250.183.14      UDP    1292
# 4        5    0.385410   192.168.137.64   142.250.183.14      UDP    1292
# ...    ...         ...              ...              ...      ...     ...
# 8100  8101  177.471066  142.250.183.206   192.168.137.64      UDP      99
# 8101  8102  177.482459   192.168.137.64  142.250.183.206      UDP      76
# 8102  8103  177.768087  142.250.183.206   192.168.137.64      UDP     109
# 8103  8104  177.781802   192.168.137.64  142.250.183.206      UDP      76
# 8104  8105  178.177895  142.250.183.206   192.168.137.64      UDP     131
#
#       Info
# 0     1243
# 1     1243
# 2     1243
# 3     1243
# 4     1243
# ...

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(5)
plt.plot(df.head(500)["Length"])

# %%
df["Packets"] = float(df["Info"][0])/df["Length"]

# df["Total time"] = df["Time"].cumsum()
# df["Total packets"] = df["Packets"].cumsum()
# df["Throughput"] = float(df["Packets"][0])/df["Total time"]
df
# Out:
#        No.        Time           Source      Destination Protocol  Length  \
# 0        1    0.000000    192.168.137.1  239.255.255.250     SSDP     217
# 1        2    0.384720   192.168.137.64   142.250.183.14      UDP    1285
# 2        3    0.385031   192.168.137.64   142.250.183.14      UDP    1292
# 3        4    0.385232   192.168.137.64   142.250.183.14      UDP    1292
# 4        5    0.385410   192.168.137.64   142.250.183.14      UDP    1292
# ...    ...         ...              ...              ...      ...     ...
# 8100  8101  177.471066  142.250.183.206   192.168.137.64      UDP      99
# 8101  8102  177.482459   192.168.137.64  142.250.183.206      UDP      76
# 8102  8103  177.768087  142.250.183.206   192.168.137.64      UDP     109
# 8103  8104  177.781802   192.168.137.64  142.250.183.206      UDP      76
# 8104  8105  178.177895  142.250.183.206   192.168.137.64      UDP     131
#
#       Info    Packets
# 0     1243   5.728111
# 1     1243   0.967315
# ...

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(5)
plt.plot(df["Packets"].head(500))

# %%
##KDCup1999 Dataset

# %%
kddcup = pd.read_csv("corrected")

# %%
kddcup
# Out:
#         0  udp  private  SF  105  146  0.1  0.2  0.3  0.4  ...  254  1.00.1  \
# 0       0  udp  private  SF  105  146    0    0    0    0  ...  254     1.0
# 1       0  udp  private  SF  105  146    0    0    0    0  ...  254     1.0
# 2       0  udp  private  SF  105  146    0    0    0    0  ...  254     1.0
# 3       0  udp  private  SF  105  146    0    0    0    0  ...  254     1.0
# 4       0  udp  private  SF  105  146    0    0    0    0  ...  255     1.0
# ...    ..  ...      ...  ..  ...  ...  ...  ...  ...  ...  ...  ...     ...
# 311023  0  udp  private  SF  105  147    0    0    0    0  ...  255     1.0
# 311024  0  udp  private  SF  105  147    0    0    0    0  ...  255     1.0
# 311025  0  udp  private  SF  105  147    0    0    0    0  ...  255     1.0
# 311026  0  udp  private  SF  105  147    0    0    0    0  ...  255     1.0
# 311027  0  udp  private  SF  105  147    0    0    0    0  ...  255     1.0
#
# ...

# %%
##Firewall dataset

# %%
firewall_app = pd.read_csv("Application filtering logs.csv")

# %%
firewall_app
# Out:
#                        Time                                  Blade  Action  \
# 0    Sep 1, 2022 3:32:46 PM                    Application Control  Accept
# 1    Sep 1, 2022 3:32:46 PM      Application Control,URL Filtering  Accept
# 2    Sep 1, 2022 3:32:46 PM                    Application Control  Accept
# 3    Sep 1, 2022 3:32:46 PM                    Application Control  Accept
# 4    Sep 1, 2022 3:32:46 PM  Content Awareness,Application Control  Accept
# ..                      ...                                    ...     ...
# 995  Sep 1, 2022 3:31:17 PM                    Application Control  Accept
# 996  Sep 1, 2022 3:31:17 PM                    Application Control  Accept
# 997  Sep 1, 2022 3:31:17 PM                    Application Control  Accept
# 998  Sep 1, 2022 3:31:17 PM                    Application Control  Accept
# 999  Sep 1, 2022 3:31:17 PM                    Application Control  Accept
#
# ...

# %%
firewall_url = pd.read_csv("URL Filtering logs.csv")
firewall_url
# Out:
#                        Time         Creation Time   Interface Direction  \
# 0                   ﻿"Sep 1      2022 3:31:56 PM"  2022-09-01T10:01:56Z
# 1    Sep 1, 2022 3:31:56 PM  2022-09-01T10:01:56Z               inbound
# 2    Sep 1, 2022 3:31:56 PM  2022-09-01T10:01:56Z               inbound
# 3    Sep 1, 2022 3:31:56 PM  2022-09-01T10:01:56Z               inbound
# 4    Sep 1, 2022 3:31:56 PM  2022-09-01T10:01:56Z               inbound
# ..                      ...                   ...                   ...
# 995  Sep 1, 2022 3:31:20 PM  2022-09-01T10:01:20Z              outbound
# 996  Sep 1, 2022 3:31:20 PM  2022-09-01T10:01:20Z               inbound
# 997  Sep 1, 2022 3:31:20 PM  2022-09-01T10:01:20Z               inbound
# 998  Sep 1, 2022 3:31:20 PM  2022-09-01T10:01:20Z               inbound
# 999  Sep 1, 2022 3:31:20 PM  2022-09-01T10:01:20Z               inbound
#
#                           Policy Rule UID  \
# 0                                 inbound
# ...
