# %%
import pandas as pd
import matplotlib.pyplot as plt
import string
import numpy as np
from datetime import datetime
import time
import scipy
from math import e
df_attack_test = pd.read_csv("Dataset/DDosAttack.csv")
df_idle = pd.read_csv("Dataset/IdleSystem.csv")
df_working = pd.read_csv("Dataset/WorkingSystem.csv")
# df_working = pd.read_csv("Dataset/working data one day.csv")
df_working = pd.read_csv("Dataset/working lab.csv")
df_attack = pd.read_csv("Dataset/Dos_10k.csv")
df_lab = pd.read_csv("Dataset/working lab.csv")

# DDoS dataset
df_ddos_g = pd.read_csv("Dataset/DDos Gowri.csv")
df_ddos_m = pd.read_csv("Dataset/DDos Mukesh.csv")
df_ddos_l = pd.read_csv("Dataset/DDos Likhita.csv")
df_ddos_s = pd.read_csv("Dataset/DDos Sumedha.csv")
df_ddos_attack = pd.concat([df_ddos_g,df_ddos_m,df_ddos_l,df_ddos_s])

# %% [markdown]
# # Notes:

# %% [raw]
# * Idle system :
#     total packets : 151781
#     duration : 20394
#     7.44
# * working system :
#     total packets : 168034
#     duration : 25019
#     6.71
# * system under attack :
#     total packets : 25538
#     duration : 213297
#     286.6

# %% [markdown]
# # Calculating normal network threshold

# %%
len(df_working),len(df_idle),len(df_ddos_attack)
# Out:
# (1933, 567, 64993)

# %%
# ls = [df_idle , df_idle , df_attack, df_attack, df_idle, df_idle, df_working, df_idle, df_idle, df_working]
df_idle["Attack"] = -1
df_working["Attack"] = -1
df_attack["Attack"] = 1
df_attack = df_attack[df_attack["Remote Address"] == '10.0.2.4'][:2000]
ls_working = [df_working,df_working,df_working,df_working,df_working,df_working]
df_working = pd.concat(ls_working)
ls = [df_idle,df_working, df_working,df_attack,df_working,df_attack,df_working,df_idle]
df_train = pd.concat(ls)
df_train

# len(df_working),len(df_idle),len(df_attack)
# Out:
#      Index Protocol Local Address   Remote Address  Local Port  Remote Port  \
# 0        1      TCP     10.0.2.15      41.63.105.0     49699.0         80.0
# 1        2      TCP     10.0.2.15    41.63.105.128     49709.0         80.0
# 2        3      TCP     10.0.2.15    41.63.105.128     49698.0         80.0
# 3        4      TCP     10.0.2.15   117.18.232.240     49696.0         80.0
# 4        5      TCP     10.0.2.15    41.63.105.128     49694.0         80.0
# ..     ...      ...           ...              ...         ...          ...
# 562    563      UDP     10.0.2.15  239.255.255.250     58540.0       1900.0
# 563    564      UDP     10.0.2.15      192.168.0.1     52927.0         53.0
# 564    565      TCP     10.0.2.15   104.120.154.29     50119.0        443.0
# 565    566      TCP     10.0.2.15    41.63.105.128     50120.0         80.0
# 566    567      TCP     10.0.2.15      41.63.105.0     50121.0         80.0
#
# ...

# %%
len(df_train[df_train["Attack"]==-1]),len(df_train[df_train["Attack"]==1])
# Out:
# (47526, 4000)

# %%
df_train = df_train.drop(["Index","Local Host","Remote Host"],axis=1)
# dropping the rows having NaN values
# df = df.dropna(subset=["Data Speed"])
# To reset the indices
df_train = df_train.reset_index(drop = True)
df_train
# Out:
#       Protocol Local Address   Remote Address  Local Port  Remote Port  \
# 0          TCP     10.0.2.15      41.63.105.0     49699.0         80.0
# 1          TCP     10.0.2.15    41.63.105.128     49709.0         80.0
# 2          TCP     10.0.2.15    41.63.105.128     49698.0         80.0
# 3          TCP     10.0.2.15   117.18.232.240     49696.0         80.0
# 4          TCP     10.0.2.15    41.63.105.128     49694.0         80.0
# ...        ...           ...              ...         ...          ...
# 51521      UDP     10.0.2.15  239.255.255.250     58540.0       1900.0
# 51522      UDP     10.0.2.15      192.168.0.1     52927.0         53.0
# 51523      TCP     10.0.2.15   104.120.154.29     50119.0        443.0
# 51524      TCP     10.0.2.15    41.63.105.128     50120.0         80.0
# 51525      TCP     10.0.2.15      41.63.105.0     50121.0         80.0
#
#       Service Name Packets        Data Size       Total Size     Data Speed  \
# ...

# %%
df_train["Throughput"] = 0
df_train["Duration in seconds"] = 0
type(df_train["Total Size"][0])
for i in range(0,len(df_train["Total Size"])):
    df_train["Total Size"][i] = df_train["Total Size"][i].translate(str.maketrans('', '', string.punctuation))
    df_train["Total Size"][i] = int(df_train["Total Size"][i].split(' ')[0])
    
    df_train["Data Size"][i] = df_train["Data Size"][i].translate(str.maketrans('', '', string.punctuation))
    df_train["Data Size"][i] = int(df_train["Data Size"][i].split(' ')[0])
    
#     df_s["Data speed"][i] = df_s["Data speed"][i].split(' ')[0]
#     print(i)
    df_train["Data Speed"][i] = float(str(df_train["Data Speed"][i]).split(' ')[0])
#     df_s["Data speed"][i] = float(df_s["Data speed"][i])

    t = datetime.strptime(df_train["Duration"][i].split('.')[0], '%M:%S').time()
    df_train["Duration in seconds"][i] = t.hour*3600 + t.minute*60 + t.second
    
    df_train["Packets"][i] = df_train["Packets"][i].translate(str.maketrans('', '', string.punctuation))
    df_train["Packets"][i] = int(df_train["Packets"][i].split(' ')[0])
    df_train["Packets"][i] = int(df_train["Packets"][i])
    
#     df["Throughput"] -
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
df_train["Throughput"] = 0.0
for i in range(0,len(df_train["Total Size"])):
    val = df_train["Packets"][i]/df_train["Duration in seconds"][i]
    if val==np.inf or val==-np.inf:
        val = 10**15
    df_train["Throughput"][i] = val
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in longlong_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_train
# Out:
#       Protocol Local Address   Remote Address  Local Port  Remote Port  \
# 0          TCP     10.0.2.15      41.63.105.0     49699.0         80.0
# 1          TCP     10.0.2.15    41.63.105.128     49709.0         80.0
# 2          TCP     10.0.2.15    41.63.105.128     49698.0         80.0
# 3          TCP     10.0.2.15   117.18.232.240     49696.0         80.0
# 4          TCP     10.0.2.15    41.63.105.128     49694.0         80.0
# ...        ...           ...              ...         ...          ...
# 51521      UDP     10.0.2.15  239.255.255.250     58540.0       1900.0
# 51522      UDP     10.0.2.15      192.168.0.1     52927.0         53.0
# 51523      TCP     10.0.2.15   104.120.154.29     50119.0        443.0
# 51524      TCP     10.0.2.15    41.63.105.128     50120.0         80.0
# 51525      TCP     10.0.2.15      41.63.105.0     50121.0         80.0
#
#       Service Name Packets Data Size Total Size Data Speed  \
# ...

# %%
throughput = df_train["Throughput"]
throughput.replace([np.inf, -np.inf], np.nan, inplace=True)
throughput.dropna(how="all", inplace=True)

mode = throughput.mode()
stdev = throughput.std()
mean = throughput.mean()
median = throughput.median()
var = stdev**0.5
mean,stdev,mode,var,mean-stdev
# Out:
# (620152932500097.2, 485353319383266.5, 0    1.000000e+15
#  dtype: float64, 22030735.78851298, 134799613116830.75)

# %%
import seaborn as sns
# from numpy import mean,median
sns.kdeplot(data=df_train)
# sns.barplot(data = df_train,estimator=median)

# %% [markdown]
# # Test

# %%
# ## DDoS attack dataset preprocess
# df_ddos_attack = df_ddos_attack[:5000]
# df_ddos_attack = df_ddos_attack.drop(["Index","Local Host","Remote Host"],axis=1)
# # dropping the rows having NaN values
# # df = df.dropna(subset=["Data Speed"])
# # To reset the indices
# df_ddos_attack = df_ddos_attack.reset_index(drop = True)
# df_ddos_attack["Attack"] = 1

# df_ddos_attack["Throughput"] = 0.0
# df_ddos_attack["Duration in seconds"] = 0
# type(df_ddos_attack["Total Size"][0])
# for i in range(0,len(df_ddos_attack["Total Size"])):
#     df_ddos_attack["Total Size"][i] = df_ddos_attack["Total Size"][i].translate(str.maketrans('', '', string.punctuation))
#     df_ddos_attack["Total Size"][i] = int(df_ddos_attack["Total Size"][i].split(' ')[0])
    
#     df_ddos_attack["Data Size"][i] = df_ddos_attack["Data Size"][i].translate(str.maketrans('', '', string.punctuation))
#     df_ddos_attack["Data Size"][i] = int(df_ddos_attack["Data Size"][i].split(' ')[0])
    
# #     df_s["Data speed"][i] = df_s["Data speed"][i].split(' ')[0]
# #     print(i)
#     df_ddos_attack["Data Speed"][i] = float(str(df_ddos_attack["Data Speed"][i]).split(' ')[0])
# #     df_s["Data speed"][i] = float(df_s["Data speed"][i])

#     t = datetime.strptime(df_ddos_attack["Duration"][i].split('.')[0], '%M:%S').time()
#     df_ddos_attack["Duration in seconds"][i] = t.hour*3600 + t.minute*60 + t.second
    
#     df_ddos_attack["Packets"][i] = df_ddos_attack["Packets"][i].translate(str.maketrans('', '', string.punctuation))
#     df_ddos_attack["Packets"][i] = int(df_ddos_attack["Packets"][i].split(' ')[0])
#     df_ddos_attack["Packets"][i] = int(df_ddos_attack["Packets"][i])
    
# #     df["Throughput"] - 


#     val = df_ddos_attack["Packets"][i]/df_ddos_attack["Duration in seconds"][i]
#     if val==np.inf or val==-np.inf:
#         val = 10**15
#     df_ddos_attack["Throughput"][i] = val
    
# df_ddos_attack

# %%
df_idle["Attack"] = -1
df_working["Attack"] = -1
df_attack["Attack"] = 1
df_lab["Attack"] = -1
ls = [df_idle,df_attack,df_idle,df_working]
# ls = [df_ddos_attack]
# ls = [df_attack]
df_test = pd.concat(ls)
# df_test = df_test[:4000]
df_test
# Out:
#       Index Protocol   Local Address  Remote Address  Local Port  Remote Port  \
# 0         1      TCP       10.0.2.15     41.63.105.0     49699.0         80.0
# 1         2      TCP       10.0.2.15   41.63.105.128     49709.0         80.0
# 2         3      TCP       10.0.2.15   41.63.105.128     49698.0         80.0
# 3         4      TCP       10.0.2.15  117.18.232.240     49696.0         80.0
# 4         5      TCP       10.0.2.15   41.63.105.128     49694.0         80.0
# ...     ...      ...             ...             ...         ...          ...
# 1928   1929      TCP  192.168.137.84  52.109.124.115     52424.0        443.0
# 1929   1930      UDP  192.168.137.84   192.168.137.1     49171.0         53.0
# 1930   1931      TCP  192.168.137.84  52.109.124.115     52425.0        443.0
# 1931   1932      UDP  192.168.137.84   192.168.137.1     54943.0         53.0
# 1932   1933      TCP  192.168.137.84  142.250.76.206     52426.0        443.0
#
# ...

# %%
df_test = df_test.drop(["Index","Local Host","Remote Host"],axis=1)
# dropping the rows having NaN values
# df_test = df.dropna(subset=["Data Speed"])
# To reset the indices
df_test = df_test.reset_index(drop = True)

df_test["Throughput"] = 0
df_test["Duration in seconds"] = 0
type(df_test["Total Size"][0])
for i in range(0,len(df_test["Total Size"])):
    df_test["Total Size"][i] = df_test["Total Size"][i].translate(str.maketrans('', '', string.punctuation))
    df_test["Total Size"][i] = int(df_test["Total Size"][i].split(' ')[0])
    
    df_test["Data Size"][i] = df_test["Data Size"][i].translate(str.maketrans('', '', string.punctuation))
    df_test["Data Size"][i] = int(df_test["Data Size"][i].split(' ')[0])
    
#     df_s["Data speed"][i] = df_s["Data speed"][i].split(' ')[0]
#     print(i)
    df_test["Data Speed"][i] = float(str(df_test["Data Speed"][i]).split(' ')[0])
#     df_s["Data speed"][i] = float(df_s["Data speed"][i])

    t = datetime.strptime(df_test["Duration"][i].split('.')[0], '%M:%S').time()
    df_test["Duration in seconds"][i] = t.hour*3600 + t.minute*60 + t.second
    
    df_test["Packets"][i] = df_test["Packets"][i].translate(str.maketrans('', '', string.punctuation))
    df_test["Packets"][i] = int(df_test["Packets"][i].split(' ')[0])
    df_test["Packets"][i] = int(df_test["Packets"][i])
    
#     df["Throughput"] - 
df_test
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_test["Throughput"] = 0.0
for i in range(0,len(df_test["Total Size"])):
    val = df_test["Packets"][i]/df_test["Duration in seconds"][i]
    if val==np.inf or val==-np.inf:
        val = 10**15
    df_test["Throughput"][i] = val
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in longlong_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# df_test["Anomaly"] = -1
# df_test.replace(np.nan,np.inf,inplace=True)
# for i in range(0,len(df_test["Total Size"])):
#     if(abs(df_test["Throughput"][i]-mean)<stdev):
# #         print(df["Throughput"][i],mean)
#         df_test["Anomaly"][i] = 1   
df_test["Anomaly"] = 1
df_test.replace(np.nan,np.inf,inplace=True)
for i in range(0,len(df_test["Total Size"])):
    if(abs(df_test["Throughput"][i]-mean)<stdev):
#         print(df["Throughput"][i],mean)
        df_test["Anomaly"][i] = -1
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
from sklearn.metrics import confusion_matrix,precision_score,accuracy_score,f1_score, classification_report
import seaborn as sn
tn, fp, fn, tp = confusion_matrix(df_test["Attack"], df_test["Anomaly"]).ravel()
precision = precision_score(df_test["Attack"], df_test["Anomaly"])
accuracy = accuracy_score(df_test["Attack"], df_test["Anomaly"])
f1_score = f1_score(df_test["Attack"], df_test["Anomaly"])

# %%
(tn, fp, fn, tp),precision,accuracy
# Out:
# ((7310, 5422, 1999, 1), 0.00018439977872026554, 0.4962666304642954)

# %%
sn.heatmap(confusion_matrix(df_test["Attack"], df_test["Anomaly"]))

# %% [markdown]
# # Entropy

# %%
def entropy_calc(data):
    p_data = data.value_counts()           # counts occurrence of each value
    entropy = scipy.stats.entropy(p_data)  # get entropy from counts
    return entropy


df_test["Entropy throughput"] = 0.0
df_test["Entropy Duration"] = 0.0
df_test["Entropy packets"] = 0.0

df_train["Entropy throughput"] = 0.0
df_train["Entropy Duration"] = 0.0
df_train["Entropy packets"] = 0.0

for i in range(0,len(df_test["Total Size"])):
    df_test["Entropy throughput"][i] = entropy_calc(df_test["Throughput"][:i+1])
    df_test["Entropy Duration"][i] = entropy_calc(df_test["Duration in seconds"][:i+1])
    df_test["Entropy packets"][i] = entropy_calc(df_test["Packets"][:i+1])
    
for i in range(0,len(df_train["Total Size"])):
    df_train["Entropy throughput"][i] = entropy_calc(df_train["Throughput"][:i+1])
    df_train["Entropy Duration"][i] = entropy_calc(df_train["Duration in seconds"][:i+1])
    df_train["Entropy packets"][i] = entropy_calc(df_train["Packets"][:i+1])
    
# df_test
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
plt.xlabel("SNo")
plt.ylabel("Throughput entropy")
plt.plot(df_test["Entropy packets"])
plt.figure()
plt.plot(df_test["Entropy throughput"])
plt.figure()
plt.plot(df_test["Entropy Duration"])

# %%
df_test["Anomaly throughput entropy based"] = -1
df_test["Anomaly duration entropy based"] = -1

checkval = df_test["Entropy throughput"][0]
check_duration = df_test["Entropy Duration"][0]

for i in range(0,len(df_test["Total Size"])):
    if df_test["Entropy throughput"][i]<checkval:
        df_test["Anomaly throughput entropy based"][i] = 1
    if df_test["Entropy Duration"][i]<check_duration:
        df_test["Anomaly duration entropy based"][i] = 1
    
    checkval = df_test["Entropy throughput"][i]
    check_duration = df_test["Entropy Duration"][i]
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
tn, fp, fn, tp = confusion_matrix(df_test["Attack"], df_test["Anomaly duration entropy based"]).ravel()
precision = precision_score(df_test["Attack"], df_test["Anomaly duration entropy based"])
accuracy = accuracy_score(df_test["Attack"], df_test["Anomaly duration entropy based"])
(tn,fp,fn,tp), precision, accuracy
# Out:
# ((7118, 27324, 1, 2999), 0.0989018236981829, 0.27020458308851025)

# %%
sn.heatmap(confusion_matrix(df_test["Attack"], df_test["Anomaly"]))

# %% [markdown]
# # Entropy and throughput

# %%
df_test
df_test["Anomaly threshold entropy"] = -1
df_test.replace(np.nan,np.inf,inplace=True)
checkval = 0
for i in range(0,len(df_test["Total Size"])):
    if(df_test["Throughput"][i]>mean and df_test["Entropy throughput"][i]<checkval):
#         print(df["Throughput"][i],mean)
        df_test["Anomaly threshold entropy"][i] = 1
    checkval = df_test["Entropy throughput"][i]
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
tn, fp, fn, tp = confusion_matrix(df_test["Attack"], df_test["Anomaly threshold entropy"]).ravel()
precision = precision_score(df_test["Attack"], df_test["Anomaly threshold entropy"])
accuracy = accuracy_score(df_test["Attack"], df_test["Anomaly threshold entropy"])
(tn,fp,fn,tp), precision, accuracy
# Out:
# ((1967, 783, 1, 2999), 0.7929666842940243, 0.8636521739130435)

# %%
################################################################################################################################

# %%
# ls = [df_idle , df_idle , df_attack, df_attack, df_idle, df_idle, df_working, df_idle, df_idle, df_working]
df_idle["Attack"] = -1
df_working["Attack"] = -1
df_attack["Attack"] = 1
df_attack = df_attack[df_attack["Remote Address"] == '10.0.2.4'][:3000]
ls = [df_idle, df_working,df_attack,df_working, df_idle, df_attack, df_working]
# ls = [df_attack]
df = pd.concat(ls)
df
# Out:
#       Index Protocol   Local Address  Remote Address  Local Port  Remote Port  \
# 0         1      TCP       10.0.2.15     41.63.105.0     49699.0         80.0
# 1         2      TCP       10.0.2.15   41.63.105.128     49709.0         80.0
# 2         3      TCP       10.0.2.15   41.63.105.128     49698.0         80.0
# 3         4      TCP       10.0.2.15  117.18.232.240     49696.0         80.0
# 4         5      TCP       10.0.2.15   41.63.105.128     49694.0         80.0
# ...     ...      ...             ...             ...         ...          ...
# 1928   1929      TCP  192.168.137.84  52.109.124.115     52424.0        443.0
# 1929   1930      UDP  192.168.137.84   192.168.137.1     49171.0         53.0
# 1930   1931      TCP  192.168.137.84  52.109.124.115     52425.0        443.0
# 1931   1932      UDP  192.168.137.84   192.168.137.1     54943.0         53.0
# 1932   1933      TCP  192.168.137.84  142.250.76.206     52426.0        443.0
#
# ...

# %%
df = df.drop(["Index","Local Host","Remote Host"],axis=1)
# dropping the rows having NaN values
# df = df.dropna(subset=["Data Speed"])
# To reset the indices
df = df.reset_index(drop = True)
df
# Out:
#       Protocol   Local Address  Remote Address  Local Port  Remote Port  \
# 0          TCP       10.0.2.15     41.63.105.0     49699.0         80.0
# 1          TCP       10.0.2.15   41.63.105.128     49709.0         80.0
# 2          TCP       10.0.2.15   41.63.105.128     49698.0         80.0
# 3          TCP       10.0.2.15  117.18.232.240     49696.0         80.0
# 4          TCP       10.0.2.15   41.63.105.128     49694.0         80.0
# ...        ...             ...             ...         ...          ...
# 39923      TCP  192.168.137.84  52.109.124.115     52424.0        443.0
# 39924      UDP  192.168.137.84   192.168.137.1     49171.0         53.0
# 39925      TCP  192.168.137.84  52.109.124.115     52425.0        443.0
# 39926      UDP  192.168.137.84   192.168.137.1     54943.0         53.0
# 39927      TCP  192.168.137.84  142.250.76.206     52426.0        443.0
#
#       Service Name Packets      Data Size     Total Size     Data Speed  \
# ...

# %% [raw]
# # print(df["Duration"].to_string())
# t = datetime.strptime(df["Duration"][0].split('.')[0], '%M:%S')
# t1 = datetime.strptime(df["Duration"][1].split('.')[0], '%M:%S')
# t = t.time()
# t, t.hour , t.minute, t.second, (t.hour*3600 + t.minute*60+ t.second)

# %% [raw]
# t = t1.time()
# t, t.hour , t.minute, t.second, (t.hour*3600 + t.minute*60+ t.second)

# %%
df["Throughput"] = 0
df["Duration in seconds"] = 0
type(df["Total Size"][0])
for i in range(0,len(df["Total Size"])):
    df["Total Size"][i] = df["Total Size"][i].translate(str.maketrans('', '', string.punctuation))
    df["Total Size"][i] = int(df["Total Size"][i].split(' ')[0])
    
    df["Data Size"][i] = df["Data Size"][i].translate(str.maketrans('', '', string.punctuation))
    df["Data Size"][i] = int(df["Data Size"][i].split(' ')[0])
    
#     df_s["Data speed"][i] = df_s["Data speed"][i].split(' ')[0]
#     print(i)
    df["Data Speed"][i] = float(str(df["Data Speed"][i]).split(' ')[0])
#     df_s["Data speed"][i] = float(df_s["Data speed"][i])

    t = datetime.strptime(df["Duration"][i].split('.')[0], '%M:%S').time()
    df["Duration in seconds"][i] = t.hour*3600 + t.minute*60 + t.second
    
    df["Packets"][i] = df["Packets"][i].translate(str.maketrans('', '', string.punctuation))
    df["Packets"][i] = int(df["Packets"][i].split(' ')[0])
    df["Packets"][i] = int(df["Packets"][i])
    
#     df["Throughput"] -
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %% [raw]
# type(df["Duration"][0])

# %%
df["Duration in seconds"].sum(),len(df["Packets"])
# print(df["Duration in seconds"])
# Out:
# (116241, 9558)

# %%
# plt.plot(df["Duration in seconds"])

# %%
# f = plt.figure()
# f.set_figwidth(20)
# f.set_figheight(9)
# plt.xlabel("S No")
# plt.ylabel("Number of packets")
# plt.plot(df["Packets"])

# %%
# plt.plot(df["Data Speed"])

# %%
# df

# %%
df["Throughput"] = 0.0
for i in range(0,len(df["Total Size"])):
    val = df["Packets"][i]/df["Duration in seconds"][i]
    if val==np.inf or val==-np.inf:
        val = 10**15
    df["Throughput"][i] = val
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in longlong_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# df

# %%
f = plt.figure()
f.set_figwidth(30)
f.set_figheight(10)
plt.plot(df["Throughput"])

# %%
throughput = df["Throughput"]

# %%
throughput.replace([np.inf, -np.inf], np.nan, inplace=True)
throughput.dropna(how="all", inplace=True)
throughput
# Out:
# 0        6.687500
# 1        2.769231
# 2       11.461538
# 3        6.705882
# 4        4.000000
#           ...
# 9553     4.000000
# 9554     4.000000
# 9555     2.333333
# 9556     2.666667
# 9557     2.666667
# Name: Throughput, Length: 9558, dtype: float64

# %%
mode = throughput.mode()
stdev = throughput.std()
stdev
# Out:
# 444917908585371.06

# %%
median = throughput.median()
median
# Out:
# 1000000000000000.0

# %%
mean = throughput.mean()
mean
# Out:
# 728185812931576.9

# %%
df["Anomaly"] = -1
df.replace(np.nan,np.inf,inplace=True)
for i in range(0,len(df["Total Size"])):
    if(df["Throughput"][i]>stdev):
#         print(df["Throughput"][i],mean)
        df["Anomaly"][i] = 1
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
f = plt.figure()
f.set_figwidth(50)
f.set_figheight(9)
plt.plot(df["Anomaly"])

# %%
from sklearn.metrics import confusion_matrix,precision_score,accuracy_score,f1_score, classification_report
import seaborn as sn
tn, fp, fn, tp = confusion_matrix(df["Attack"], df["Anomaly"]).ravel()
precision = precision_score(df["Attack"], df["Anomaly"])
accuracy = accuracy_score(df["Attack"], df["Anomaly"])
f1_score = f1_score(df["Attack"], df["Anomaly"])

# %%
(tn,fp,fn,tp), precision, accuracy, f1_score
# Out:
# ((2596, 962, 2, 5998),
#  0.8617816091954023,
#  0.8991420799330404,
#  0.9256172839506174)

# %%
sn.heatmap(confusion_matrix(df["Attack"], df["Anomaly"]))

# %%
print(classification_report(df["Attack"], df["Anomaly"]))
# Out:
#               precision    recall  f1-score   support
#
#           -1       1.00      0.73      0.84      3558
#            1       0.86      1.00      0.93      6000
#
#     accuracy                           0.90      9558
#    macro avg       0.93      0.86      0.88      9558
# weighted avg       0.91      0.90      0.90      9558

# %%
miss_rate = fn/(fn+tp)
miss_rate
# Out:
# 0.0003333333333333333

# %% [markdown]
# #  On testing dataset

# %%
df_attack_test["Attack"] = 1
df_attack_test = df_attack_test.drop(["Index","Local Host","Remote Host"],axis=1)
# dropping the rows having NaN values
# df = df.dropna(subset=["Data Speed"])
# To reset the indices
df_attack_test = df_attack_test.reset_index(drop = True)

# df_attack_test["Throughput"] = 0
df_attack_test["Duration in seconds"] = 0
type(df_attack_test["Total Size"][0])
for i in range(0,len(df_attack_test["Total Size"])):
    df_attack_test["Total Size"][i] = df_attack_test["Total Size"][i].translate(str.maketrans('', '', string.punctuation))
    df_attack_test["Total Size"][i] = int(df_attack_test["Total Size"][i].split(' ')[0])
    
    df_attack_test["Data Size"][i] = df_attack_test["Data Size"][i].translate(str.maketrans('', '', string.punctuation))
    df_attack_test["Data Size"][i] = int(df_attack_test["Data Size"][i].split(' ')[0])
    
#     df_s["Data speed"][i] = df_s["Data speed"][i].split(' ')[0]
#     print(i)
    df_attack_test["Data Speed"][i] = float(str(df_attack_test["Data Speed"][i]).split(' ')[0])
#     df_s["Data speed"][i] = float(df_s["Data speed"][i])

    t = datetime.strptime(df_attack_test["Duration"][i].split('.')[0], '%M:%S').time()
    df_attack_test["Duration in seconds"][i] = t.hour*3600 + t.minute*60 + t.second
    
    df_attack_test["Packets"][i] = df_attack_test["Packets"][i].translate(str.maketrans('', '', string.punctuation))
    df_attack_test["Packets"][i] = int(df_attack_test["Packets"][i].split(' ')[0])
    df_attack_test["Packets"][i] = int(df_attack_test["Packets"][i])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-72628c35390a> in <module>
#      10 type(df_attack_test["Total Size"][0])
#      11 for i in range(0,len(df_attack_test["Total Size"])):
# ---> 12     df_attack_test["Total Size"][i] = df_attack_test["Total Size"][i].translate(str.maketrans('', '', string.punctuation))
#      13     df_attack_test["Total Size"][i] = int(df_attack_test["Total Size"][i].split(' ')[0])
#      14
#
# AttributeError: 'int' object has no attribute 'translate'

# %%
df_attack_test
# Out:
#      Protocol  Local Address   Remote Address  Local Port  Remote Port  \
# 0         UDP  192.168.0.119  239.255.255.250       53085         1900
# 1         UDP  192.168.0.191        10.0.2.15       50554            1
# 2         UDP  192.168.0.191        10.0.2.15        4005        26924
# 3         UDP  192.168.0.191        10.0.2.15       50554            2
# 4         UDP  192.168.0.191        10.0.2.15       50554            3
# ...       ...            ...              ...         ...          ...
# 3559      UDP  192.168.0.191        10.0.2.15       50554         8231
# 3560      UDP  192.168.0.191        10.0.2.15       50554         8232
# 3561      UDP  192.168.0.191        10.0.2.15       50554         8233
# 3562      UDP  192.168.0.191        10.0.2.15       50554         8234
# 3563      UDP  192.168.0.191        10.0.2.15       50554         8235
#
#      Service Name Packets Data Size Total Size Data Speed  \
# ...

# %%
# df_attack_test["Throughput"] = 0.0
# size = len(df["Packets"])
# for i in range(0,len(df_attack_test["Total Size"])):
# #     print(i)
#     val = df_attack_test["Packets"][i]/df_attack_test["Duration in seconds"][i]
#     if val==np.inf or val==-np.inf:
#         val = 10**15
#     df_attack_test["Throughput"][i] = val
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in longlong_scalars
#   after removing the cwd from sys.path.
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df_attack_test["Anomaly"] = -1
df_attack_test["Throughput"] = 0.0
df_attack_test.replace(np.nan,np.inf,inplace=True)
size = len(df["Packets"])
for i in range(0,len(df_attack_test["Total Size"])):
#     df["Throughput"][i] = df_attack_test["Packets"][i]/df_attack_test["Duration in seconds"][i]
#     mean = (mean*size + df["Throughput"][i])/(size + 1)
#     size = size + 1
    if(df_attack_test["Throughput"][i]>mean):
#         print(df["Throughput"][i],mean)
        df_attack_test["Anomaly"][i] = 1 

tn, fp, fn, tp = confusion_matrix(df_attack_test["Attack"], df_attack_test["Anomaly"]).ravel()
precision = precision_score(df_attack_test["Attack"], df_attack_test["Anomaly"])
accuracy = accuracy_score(df_attack_test["Attack"], df_attack_test["Anomaly"])
# f1_score = f1_score(df_attack_test["Attack"], df_attack_test["Anomaly"])
(tn,tp,fn,fp),precision,accuracy
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in longlong_scalars
#
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ((0, 0, 3564, 0), 0.0, 0.0)

# %% [markdown]
# # Entropy

# %%
def entropy_calc(data):
    p_data = data.value_counts()           # counts occurrence of each value
    entropy = scipy.stats.entropy(p_data)  # get entropy from counts
    return entropy
df["Entropy throughput"] = 0.0
df["Entropy Remote Address"] = 0.0
df["Entropy Remote Port"] = 0.0
df["Entropy Duration"] = 0.0
for i in range(0,len(df["Total Size"])):
    df["Entropy throughput"][i] = entropy_calc(df["Throughput"][:i+1])
    df["Entropy Remote Address"][i] = entropy_calc(df["Remote Address"][:i+1])
    df["Entropy Remote Port"][i] = entropy_calc(df["Remote Port"][:i+1])
    df["Entropy Duration"][i] = entropy_calc(df["Duration in seconds"][:i+1])
    
df
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
plt.xlabel("SNo")
plt.ylabel("Throughput entropy")
plt.plot(df["Entropy throughput"])
plt.figure()
plt.plot(df["Entropy Remote Address"])
plt.figure()
plt.plot(df["Entropy Remote Port"])
plt.figure()
plt.plot(df["Entropy Duration"])

# %%
## Entropy throughput anomaly detection
df["Anomaly entropy based"] = -1
df["Anomaly port entropy based"] = -1
df["Anomaly duration entropy based"] = -1
checkval = df["Entropy throughput"][0]
check_port = df["Entropy Remote Port"][0]
check_duration = df["Entropy Duration"][0]
for i in range(0,len(df["Total Size"])):
    if df["Entropy throughput"][i]<checkval:
        df["Anomaly entropy based"][i] = 1
    if df["Entropy Remote Port"][i]>check_port:
        df["Anomaly port entropy based"][i] = 1
    if df["Entropy Duration"][i]>check_port:
        df["Anomaly duration entropy based"][i] = 1
    check_port = df["Entropy Remote Port"][i]
    checkval = df["Entropy throughput"][i]
    check_duration = df["Entropy Duration"][i]
# df["Entropy throughput"][0],checkval,type(df["Entropy throughput"][0]),type(checkval),df["Entropy throughput"][i]<checkval
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\Gowri\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
f = plt.figure()
f.set_figwidth(50)
f.set_figheight(9)
plt.plot(df["Anomaly entropy based"])
plt.figure()
plt.plot(df["Anomaly port entropy based"])

# %%
from sklearn.metrics import confusion_matrix,precision_score,accuracy_score,f1_score, classification_report
tn, fp, fn, tp = confusion_matrix(df["Attack"], df["Anomaly entropy based"]).ravel()
precision = precision_score(df["Attack"], df["Anomaly entropy based"])
accuracy = accuracy_score(df["Attack"], df["Anomaly entropy based"])
f1_score = f1_score(df["Attack"], df["Anomaly entropy based"])
(tn,fp,fn,tp), precision, accuracy, f1_score
# Out:
# ((3247, 311, 3001, 2999),
#  0.9060422960725075,
#  0.6534839924670434,
#  0.6442534908700323)

# %%
sn.heatmap(confusion_matrix(df["Attack"], df["Anomaly entropy based"]))

# %%
from sklearn.metrics import confusion_matrix,precision_score,accuracy_score,f1_score, classification_report
tn, fp, fn, tp = confusion_matrix(df["Attack"], df["Anomaly port entropy based"]).ravel()
precision = precision_score(df["Attack"], df["Anomaly port entropy based"])
accuracy = accuracy_score(df["Attack"], df["Anomaly port entropy based"])
f1_score = f1_score(df["Attack"], df["Anomaly port entropy based"])
(tn,fp,fn,tp), precision, accuracy, f1_score
# Out:
# ((3107, 451, 5, 5995),
#  0.9300341296928327,
#  0.9522912743251726,
#  0.9633617226418125)

# %%
from sklearn.metrics import confusion_matrix,precision_score,accuracy_score,f1_score, classification_report
tn, fp, fn, tp = confusion_matrix(df["Attack"], df["Anomaly duration entropy based"]).ravel()
precision = precision_score(df["Attack"], df["Anomaly duration entropy based"])
accuracy = accuracy_score(df["Attack"], df["Anomaly duration entropy based"])
f1_score = f1_score(df["Attack"], df["Anomaly duration entropy based"])
(tn,fp,fn,tp), precision, accuracy, f1_score
# Out:
# ((2184, 1374, 5545, 455),
#  0.24876981957353744,
#  0.27610378740322244,
#  0.11623451270915824)

# %% [markdown]
# # SVM

# %%
from sklearn.svm import OneClassSVM
from sklearn import preprocessing

my_label = preprocessing.LabelEncoder()   
   
df_train[ 'Protocol' ]= my_label.fit_transform(df_train[ 'Protocol' ])
df_test[ 'Protocol' ]= my_label.fit_transform(df_test[ 'Protocol' ])

df_train[ 'Local Address' ]= my_label.fit_transform(df_train[ 'Local Address' ])
df_test[ 'Local Address' ]= my_label.fit_transform(df_test[ 'Local Address' ])

# dfsvm = df[["Local Port","Remote Port","Packets","Data Size","Total Size","Data Speed","Capture Time","Last Packet Time","Duration","Throughput","Duration in seconds"]]
model = OneClassSVM(kernel = 'poly',degree=2,gamma = 0.00001, nu = 0.3,max_iter=150,coef0=0.5).fit(df_train[['Local Address',"Protocol","Packets","Data Size","Total Size","Throughput","Duration in seconds"]])
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\sklearn\svm\base.py:241: ConvergenceWarning: Solver terminated early (max_iter=150).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)

# %%
# df[df["Data Speed"]==np.inf]
# type(df["Data Speed"][4])
y_pred = model.predict(df_test[['Local Address',"Protocol","Packets","Data Size","Total Size","Throughput","Duration in seconds"]])

# %%
tn, fp, fn, tp = confusion_matrix(df_test["Attack"], y_pred).ravel()
precision = precision_score(df_test["Attack"], y_pred)
accuracy = accuracy_score(df_test["Attack"], y_pred)
# f1_score = f1_score(df["Attack"], y_pred)
# y_pred
print((tn,fp,fn,tp), precision, accuracy)
print(classification_report(df_test["Attack"], y_pred))
# Out:
# (5188, 7544, 0, 2000) 0.20955574182732606 0.48791745859353786
#               precision    recall  f1-score   support
#
#           -1       1.00      0.41      0.58     12732
#            1       0.21      1.00      0.35      2000
#
#     accuracy                           0.49     14732
#    macro avg       0.60      0.70      0.46     14732
# weighted avg       0.89      0.49      0.55     14732

# %% [markdown]
# # ISOLATION FOREST

# %%
from sklearn.ensemble import IsolationForest
from sklearn import preprocessing

my_label = preprocessing.LabelEncoder()   
   
df_train[ 'Protocol' ]= my_label.fit_transform(df_train[ 'Protocol' ])
df_test[ 'Protocol' ]= my_label.fit_transform(df_test[ 'Protocol' ])



model_IF = IsolationForest(contamination=float(0.5),random_state=6,max_features = 5,verbose = 1,n_jobs = 8,bootstrap=True)
model_IF.fit(df_train[["Protocol","Packets","Data Size","Total Size","Throughput","Duration in seconds"]])
scores = model_IF.decision_function(df_test[["Protocol","Packets","Data Size","Total Size","Throughput","Duration in seconds"]])
pred = model_IF.predict(df_test[["Protocol","Packets","Data Size","Total Size","Throughput","Duration in seconds"]])

tn, fp, fn, tp = confusion_matrix(df_test["Attack"], pred).ravel()
precision = precision_score(df_test["Attack"], pred)
accuracy = accuracy_score(df_test["Attack"], pred)
# f1_score = f1_score(df["Attack"], y_pred)
# y_pred
print((tn,fp,fn,tp), precision, accuracy)
print(classification_report(df_test["Attack"], pred))
sn.heatmap(confusion_matrix(df_test["Attack"], pred))
# https://towardsdatascience.com/logistic-regression-using-python-sklearn-numpy-mnist-handwriting-recognition-matplotlib-a6b31e2b166a
# Out:
# C:\Users\Gowri\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of   8 | elapsed:    1.7s remaining:    5.3s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    1.7s finished
# C:\Users\Gowri\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# (7028, 5704, 1, 1999) 0.25950928209788393 0.6127477599782786
#               precision    recall  f1-score   support
#
#           -1       1.00      0.55      0.71     12732
#            1       0.26      1.00      0.41      2000
#
# ...

# %% [markdown]
# # Isolation Forest for DDoS

# %%
df_ddos_attack = df_ddos_attack.sample(frac = 1)
df_ddos_attack["Attack"] = 1
ls_ddos_attack = [df_working,df_working,df_ddos_attack[:4000],df_working,df_idle]
ddos_attack_test = pd.concat(ls_ddos_attack)

ddos_attack_test[ 'Protocol' ]= my_label.fit_transform(ddos_attack_test[ 'Protocol' ])
pred = model_IF.predict(ddos_attack_test[["Protocol","Packets","Data Size","Total Size","Throughput","Duration in seconds"]])

tn, fp, fn, tp = confusion_matrix(ddos_attack_test["Attack"], pred).ravel()
precision = precision_score(ddos_attack_test["Attack"], pred)
accuracy = accuracy_score(ddos_attack_test["Attack"], pred)
# f1_score = f1_score(df["Attack"], y_pred)
# y_pred
print((tn,fp,fn,tp), precision, accuracy)
print(classification_report(df_test["Attack"], pred))
sn.heatmap(confusion_matrix(df_test["Attack"], pred))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-918-c8dddbeccca9> in <module>
#       5
#       6 ddos_attack_test[ 'Protocol' ]= my_label.fit_transform(ddos_attack_test[ 'Protocol' ])
# ----> 7 pred = model_IF.predict(ddos_attack_test[["Protocol","Packets","Data Size","Total Size","Throughput","Duration in seconds"]])
#       8
#       9 tn, fp, fn, tp = confusion_matrix(ddos_attack_test["Attack"], pred).ravel()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
# ...
